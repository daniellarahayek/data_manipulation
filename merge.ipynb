# %%
import pandas as pd 
consumidores = [("A","Movil"),("B","Movil"),("A","Portatil"),("A","Tablet"),
               ("B","Tablet"),("C","Portatil"),("D","Smartwatch"),("E","Consola")]
con_labels = ["Consumidor","Producto"]
con_df = pd.DataFrame.from_records(consumidores, columns = con_labels)

productores = [("a","Movil"),("a","Smartwatch"),("a","Tablet"),("b","Portatil"),
              ("c","Sobremesa"),("c","Portatil")]
prod_labels = ["Productor","Producto"]

prod_df = pd.DataFrame.from_records(productores, columns = prod_labels)

# %%
con_df
# Out:
#   Consumidor    Producto
# 0          A       Movil
# 1          B       Movil
# 2          A    Portatil
# 3          A      Tablet
# 4          B      Tablet
# 5          C    Portatil
# 6          D  Smartwatch
# 7          E     Consola

# %%
prod_df
# Out:
#   Productor    Producto
# 0         a       Movil
# 1         a  Smartwatch
# 2         a      Tablet
# 3         b    Portatil
# 4         c   Sobremesa
# 5         c    Portatil

# %%
#une todos los datos aun asi no hayan valores en las dos tablas
pd.merge(con_df,prod_df,on = "Producto", how = "outer")
# Out:
#    Consumidor    Producto Productor
# 0           A       Movil         a
# 1           B       Movil         a
# 2           A    Portatil         b
# 3           A    Portatil         c
# 4           C    Portatil         b
# 5           C    Portatil         c
# 6           A      Tablet         a
# 7           B      Tablet         a
# 8           D  Smartwatch         a
# 9           E     Consola       NaN
# 10        NaN   Sobremesa         c

# %%
# omite valores que no tienen valores en las dos tablas
pd.merge(con_df,prod_df,on = "Producto", how = "inner")
# Out:
#   Consumidor    Producto Productor
# 0          A       Movil         a
# 1          B       Movil         a
# 2          A    Portatil         b
# 3          A    Portatil         c
# 4          C    Portatil         b
# 5          C    Portatil         c
# 6          A      Tablet         a
# 7          B      Tablet         a
# 8          D  Smartwatch         a

# %%
con_df
# Out:
#   Consumidor    Producto
# 0          A       Movil
# 1          B       Movil
# 2          A    Portatil
# 3          A      Tablet
# 4          B      Tablet
# 5          C    Portatil
# 6          D  Smartwatch
# 7          E     Consola

# %%
prod_df
# Out:
#   Productor    Producto
# 0         a       Movil
# 1         a  Smartwatch
# 2         a      Tablet
# 3         b    Portatil
# 4         c   Sobremesa
# 5         c    Portatil

# %%
# solo creo un dataframe solo si los valores aparecen en los de la derecha o sea prod_df
pd.merge(con_df,prod_df,on = "Producto", how = "right")
# Out:
#   Consumidor    Producto Productor
# 0          A       Movil         a
# 1          B       Movil         a
# 2          D  Smartwatch         a
# 3          A      Tablet         a
# 4          B      Tablet         a
# 5          A    Portatil         b
# 6          C    Portatil         b
# 7        NaN   Sobremesa         c
# 8          A    Portatil         c
# 9          C    Portatil         c

# %%
# solo creo un dataframe solo si los valores aparecen en los de la izquierda o sea con_df
pd.merge(con_df,prod_df,on = "Producto", how = "left")
# Out:
#   Consumidor    Producto Productor
# 0          A       Movil         a
# 1          B       Movil         a
# 2          A    Portatil         b
# 3          A    Portatil         c
# 4          A      Tablet         a
# 5          B      Tablet         a
# 6          C    Portatil         b
# 7          C    Portatil         c
# 8          D  Smartwatch         a
# 9          E     Consola       NaN
