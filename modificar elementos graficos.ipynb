# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(0)
df = pd.read_csv("C:/Users/Daniel Lara/Downloads/2008.csv", nrows = 100000)
df = df.sample(frac = 1).head(100)

# %%
plt.scatter(x = df.DayofMonth, y= df.ArrDelay, s= df.Distance)
plt.show()

# %%
plt.scatter(x = df.DayofMonth, y= df.ArrDelay, s= df.Distance, alpha = 0.3, c = df.DayofMonth.isin([6,7]))
plt.title("retrasos")
plt.xlabel("Dia del mes")
plt.ylabel("retraso al llega")
plt.ylim([0,150])
# plt.xticks([0,15,30])
plt.text(x=25, y=115, s="Mi vuelo")
# Out:
# Text(25, 115, 'Mi vuelo')
