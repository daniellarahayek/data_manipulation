# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:/Users/Daniel Lara/Downloads/2008.csv", nrows = 1e6)

# %%
df.dropna(inplace = True, subset= ["ArrDelay","DepDelay"])

# %%
np.corrcoef(df["ArrDelay"],df["DepDelay"])
# Out:
# array([[1.        , 0.93490112],
#        [0.93490112, 1.        ]])

# %%
np.corrcoef([df["ArrDelay"],df["DepDelay"],df["DepTime"]])
# Out:
# array([[1.        , 0.93490112, 0.17978801],
#        [0.93490112, 1.        , 0.21229661],
#        [0.17978801, 0.21229661, 1.        ]])

# %%
# se deben eliminar columans que vengan como objeto

df.drop(inplace=True, columns=["Year","Cancelled","Diverted","Month"])
df.corr()
# Out:
#                    DayofMonth  DayOfWeek   DepTime  CRSDepTime   ArrTime  \
# DayofMonth           1.000000  -0.051893 -0.004149   -0.002338  0.001970
# DayOfWeek           -0.051893   1.000000  0.006505    0.010266  0.005845
# DepTime             -0.004149   0.006505  1.000000    0.967093  0.718832
# CRSDepTime          -0.002338   0.010266  0.967093    1.000000  0.701446
# ArrTime              0.001970   0.005845  0.718832    0.701446  1.000000
# CRSArrTime          -0.000563   0.007485  0.801405    0.800630  0.857240
# FlightNum           -0.005089  -0.003372 -0.001497   -0.013377 -0.011925
# ActualElapsedTime    0.009748   0.005525 -0.033971   -0.031518  0.027351
# CRSElapsedTime       0.005772   0.012497 -0.025449   -0.020645  0.031429
# AirTime              0.007797   0.009195 -0.031907   -0.027183  0.026009
# ArrDelay            -0.016971  -0.020013  0.179788    0.102853  0.073489
# DepDelay            -0.025893  -0.009137  0.212297    0.132519  0.087577
# ...

# %%
# muestra las correlaciones que hay entre columnas

corr = round(df.corr(),3)
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_17671_row0_col0, #T_17671_row1_col1, #T_17671_row2_col2, #T_17671_row3_col3, #T_17671_row4_col4, #T_17671_row5_col5, #T_17671_row6_col6, #T_17671_row7_col7, #T_17671_row8_col8, #T_17671_row9_col9, #T_17671_row10_col10, #T_17671_row11_col11, #T_17671_row12_col12, #T_17671_row13_col13, #T_17671_row14_col14, #T_17671_row15_col15, #T_17671_row16_col16, #T_17671_row17_col17, #T_17671_row18_col18, #T_17671_row19_col19 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
corr[corr >= 0.6].style.background_gradient()
# Out:
# <style type="text/css">
# ...
